# %% [markdown]
# <a href="https://colab.research.google.com/github/luizinnmm/-yr7ky557yk/blob/main/de_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as bibliotecas necessárias
import matplotlib.pyplot as plt

# Função para obter as entradas do usuário
def obter_dados():
    tipos_de_doces = input('Digite os tipos de doces separados por vírgula (ex: Chocolate, Bala, Pirulito): ').split(',')
    tipos_de_doces = [doce.strip() for doce in tipos_de_doces]  # Remover espaços extras

    quantidade_de_doces = input('Digite a quantidade de doces de cada tipo, separada por vírgula (ex: 200, 150, 100): ').split(',')
    quantidade_de_doces = [int(q) for q in quantidade_de_doces]  # Converter para inteiros

    quantidade_de_pessoas = int(input('Digite o número de pessoas: '))

    return tipos_de_doces, quantidade_de_doces, quantidade_de_pessoas

# Obter os dados do usuário
tipos_de_doces, quantidade_de_doces, quantidade_de_pessoas = obter_dados()

# Calcular a distribuição dos doces por pessoa
doces_por_pessoa = [quantidade / quantidade_de_pessoas for quantidade in quantidade_de_doces]

# Exibir as distribuições
print("\nDistribuição dos doces por pessoa:")
for i in range(len(tipos_de_doces)):
    print(f'{tipos_de_doces[i]}: {doces_por_pessoa[i]:.2f} doces por pessoa')

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(tipos_de_doces, doces_por_pessoa, color='skyblue')
plt.xlabel('Tipo de Doce')
plt.ylabel('Doces por Pessoa')
plt.title('Distribuição de Doces por Pessoa')
plt.show()
# Out:
# Digite os tipos de doces separados por vírgula (ex: Chocolate, Bala, Pirulito): bala, pacoca, sorvete
# Digite a quantidade de doces de cada tipo, separada por vírgula (ex: 200, 150, 100): 500, 250, 100
# Digite o número de pessoas: 23
#
# Distribuição dos doces por pessoa:
# bala: 21.74 doces por pessoa
# pacoca: 10.87 doces por pessoa
# sorvete: 4.35 doces por pessoa
